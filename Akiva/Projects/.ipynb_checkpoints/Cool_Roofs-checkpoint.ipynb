# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('NYC_Cool_Roofs_Buildings.csv')
data
# Out:
#                     Neighborhood  Total_Sq_Ft  \
# 0                Lower East Side         1380
# 1                Lower East Side         1694
# 2                Lower East Side         1725
# 3                Lower East Side         1896
# 4                Lower East Side         2208
# 5                Lower East Side         1694
# 6                Lower East Side         1408
# 7                Lower East Side         1656
# 8                Lower East Side         1650
# 9                Lower East Side         1804
# 10               Lower East Side         1422
# 11               Lower East Side         1311
# 12               Lower East Side         1564
# 13               Lower East Side         1042
# 14               Lower East Side         1508
# 15               Lower East Side         2706
# 16               Lower East Side         1702
# 17               Lower East Side         1694
# 18                   East Harlem         6400
# ...

# %%
neighborhood_series = data.groupby('Neighborhood')
neighborhood_series.head()
# Out:
#                     Neighborhood  Total_Sq_Ft  \
# 0                Lower East Side         1380
# 1                Lower East Side         1694
# 2                Lower East Side         1725
# 3                Lower East Side         1896
# 4                Lower East Side         2208
# 18                   East Harlem         6400
# 19                   East Harlem         6400
# 20                   East Harlem         5250
# 21                   East Harlem         2555
# 22            Bedford Stuyvesant         8000
# 23                   East Harlem        11863
# 25                        Bowery        10697
# 26              Long Island City        10406
# 27                    Greenpoint        15392
# 28                         Bronx        18900
# 29   Fleetwood Concourse Village         1541
# 30   Fleetwood-Concourse Village         3219
# 31   Fleetwood-Concourse Village         9882
# 32   Fleetwood-Concourse Village         2697
# ...

# %%
data.Zip.hist(bins=50)
plt.xlabel('zip')
plt.ylabel('count')

# %%
plt.boxplot(data.Total_Sq_Ft)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x109f17590>],
#  'caps': [<matplotlib.lines.Line2D at 0x109f23450>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x109f31750>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x109f31110>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x109f17710>,
#   <matplotlib.lines.Line2D at 0x109f17dd0>]}

# %%
plt.scatter(data.Neighborhood, data.Total_Sq_Ft)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-59a0231fba2b> in <module>()
# ----> 1 plt.scatter(data.Neighborhood, data.Total_Sq_Ft)
#
# /Users/campakiva/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, hold, **kwargs)
#    3198         ret = ax.scatter(x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3199                          vmin=vmin, vmax=vmax, alpha=alpha,
# -> 3200                          linewidths=linewidths, verts=verts, **kwargs)
#    3201         draw_if_interactive()
#    3202     finally:
#
# /Users/campakiva/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    3599                 c = np.ma.ravel(c)
#    3600
# ...
