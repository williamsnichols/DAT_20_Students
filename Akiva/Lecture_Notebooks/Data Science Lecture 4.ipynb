# %%
import pandas as pd
import numpy as np
from __future__ import division
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.mpl_style = 'default'

# %%
header_row = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num',]
heart_data = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data',sep=',',header=None,names=header_row,na_values='?')

# %%
heart_data.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num
# 0   63    1   1       145   233    1        2      150      0      2.3      3   0     6    0
# 1   67    1   4       160   286    0        2      108      1      1.5      2   3     3    2
# 2   67    1   4       120   229    0        2      129      1      2.6      2   2     7    1
# 3   37    1   3       130   250    0        0      187      0      3.5      3   0     3    0
# 4   41    0   2       130   204    0        2      172      0      1.4      1   0     3    0
# 5   56    1   2       120   236    0        0      178      0      0.8      1   0     3    0
# 6   62    0   4       140   268    0        2      160      0      3.6      3   2     3    3
# 7   57    0   4       120   354    0        0      163      1      0.6      1   0     3    0
# 8   63    1   4       130   254    0        2      147      0      1.4      2   1     7    2
# ...

# %%
heart_data.chol.head()
# Out:
# 0    233
# 1    286
# 2    229
# 3    250
# 4    204
# Name: chol, dtype: float64

# %%
heart_data[heart_data.thalach < 150]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num
# 1     67    1   4       160   286    0        2      108      1      1.5      2   3     3    2
# 2     67    1   4       120   229    0        2      129      1      2.6      2   2     7    1
# 8     63    1   4       130   254    0        2      147      0      1.4      2   1     7    2
# 10    57    1   4       140   192    0        0      148      0      0.4      2   0     6    0
# 12    56    1   3       130   256    1        2      142      1      0.6      2   1     6    2
# 18    48    0   3       130   275    0        0      139      0      0.2      1   0     3    0
# 20    64    1   1       110   211    0        2      144      1      1.8      2   0     3    0
# 24    60    1   4       130   206    0        2      132      1      2.4      2   2     7    4
# 27    66    0   1       150   226    0        0      114      0      2.6      3   0     3    0
# ...

# %%
heart_data.age[heart_data.age>heart_data.age.median()]
# Out:
# 0      63
# 1      67
# 2      67
# 6      62
# 7      57
# 8      63
# 10     57
# 15     57
# 20     64
# 21     58
# 22     58
# 23     58
# 24     60
# 26     58
# 27     66
# 30     69
# 31     60
# 32     64
# 33     59
# 37     57
# 39     61
# 40     65
# 42     71
# 43     59
# 44     61
# 45     58
# 48     65
# 51     65
# 54     60
# 62     58
# 65     60
# 66     60
# 68     59
# 70     65
# 71     67
# 72     62
# 73     65
# 75     65
# 76     60
# 79     58
# 83     68
# 90     66
# 91     62
# 92     62
# 94     63
# 96     59
# 97     60
# 102    57
# 103    71
# 106    59
# 107    57
# 108    61
# 110    61
# 114    62
# 116    58
# 118    63
# 119    65
# 121    63
# 124    65
# 129    62
# 136    70
# 137    62
# 140    59
# 141    59
# 143    64
# 144    58
# 146    57
# 149    60
# 152    67
# 154    64
# 155    70
# 157    58
# 158    60
# 159    68
# 161    77
# 163    58
# 165    57
# 170    70
# 172    59
# 173    62
# 174    64
# 175    57
# 183    59
# ...

# %%
heart_data.trestbps[heart_data.cp==4]
# Out:
# 1      160
# 2      120
# 6      140
# 7      120
# 8      130
# 9      140
# 10     140
# 17     140
# 24     130
# 28     150
# 29     110
# 31     117
# 33     135
# 35     140
# 36     120
# 37     150
# 38     132
# 40     150
# 44     130
# 47     150
# 51     120
# 52     112
# 54     130
# 55     124
# 57     110
# 60     130
# 62     128
# 64     120
# 65     145
# 68     170
# 71     125
# 72     120
# 73     110
# 74     110
# 76     125
# 79     150
# 80     104
# 81     130
# 88     138
# 90     120
# 91     160
# 95     128
# 96     110
# 97     150
# 99     122
# 100    115
# 102    128
# 106    140
# 108    120
# 109    118
# 110    145
# 111    125
# 113    132
# 117    138
# 118    130
# 119    135
# 120    130
# 121    150
# 123    140
# 126    200
# 127    110
# 129    124
# 133    140
# 136    145
# 138    120
# 146    165
# 151    102
# 153    160
# 154    120
# 155    130
# 156    140
# 157    125
# 158    140
# 161    125
# 163    100
# 165    132
# ...

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs     restecg     thalach       exang     oldpeak       slope          ca        thal         num
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000  301.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515    0.990099  149.607261    0.326733    1.039604    1.600660    0.672241    4.734219    0.937294
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198    0.994971   22.875003    0.469794    1.161075    0.616226    0.937438    1.939706    1.228536
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000    0.000000   71.000000    0.000000    0.000000    1.000000    0.000000    3.000000    0.000000
# ...

# %%
heart_data[heart_data.ca.isnull()]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num
# 166   52    1   3       138   223    0        0      169      0      0.0      1 NaN     3    0
# 192   43    1   4       132   247    1        2      143      1      0.1      2 NaN     7    1
# 287   58    1   2       125   220    0        0      144      0      0.4      2 NaN     7    0
# 302   38    1   3       138   175    0        0      173      0      0.0      1 NaN     3    0

# %%
print heart_data[285:290]

dropped_rows_heart_data = heart_data.dropna()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num
# 285   58    1   4       114   318    0        1      140      0      4.4      3   3     6    4
# 286   58    0   4       170   225    1        2      146      1      2.8      2   2     6    2
# 287   58    1   2       125   220    0        0      144      0      0.4      2 NaN     7    0
# 288   56    1   2       130   221    0        2      163      0      0.0      1   0     7    0
# 289   56    1   2       120   240    0        0      169      0      0.0      3   0     3    0

# %%
print dropped_rows_heart_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num
# 0     63    1   1       145   233    1        2      150      0      2.3      3   0     6    0
# 1     67    1   4       160   286    0        2      108      1      1.5      2   3     3    2
# 2     67    1   4       120   229    0        2      129      1      2.6      2   2     7    1
# 3     37    1   3       130   250    0        0      187      0      3.5      3   0     3    0
# 4     41    0   2       130   204    0        2      172      0      1.4      1   0     3    0
# 5     56    1   2       120   236    0        0      178      0      0.8      1   0     3    0
# 6     62    0   4       140   268    0        2      160      0      3.6      3   2     3    3
# 7     57    0   4       120   354    0        0      163      1      0.6      1   0     3    0
# 8     63    1   4       130   254    0        2      147      0      1.4      2   1     7    2
# ...

# %%
dropped_ca_thal_heart_data = heart_data.dropna(1)
print dropped_ca_thal_heart_data[285:290]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  num
# 285   58    1   4       114   318    0        1      140      0      4.4      3    4
# 286   58    0   4       170   225    1        2      146      1      2.8      2    2
# 287   58    1   2       125   220    0        0      144      0      0.4      2    0
# 288   56    1   2       130   221    0        2      163      0      0.0      1    0
# 289   56    1   2       120   240    0        0      169      0      0.0      3    0
