# %%
import pandas as pd
import numpy as np
import csv as csv
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn.linear_model
import sklearn.svm
from datetime import datetime, date, time
from IPython.display import Image
# %matplotlib inline

import sklearn.cross_validation

from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression


data_csv = pd.read_csv('Raw_Data1.csv')
print data_csv.head()
print data_csv.describe()
# Out:
#    Transaction_ID                            Products        City  \
# 0             215                         Green Label      McLean
# 1             218                         Black Label    New York
# 2             170                         Black Label       Davis
# 3             228         American Style Pepper Sauce     Norwalk
# 4             394  Hamajang Kiawe Smoked Ghost Pepper  Copenhagen
#
#    Previous_Sessions  Days_Since_Last_Session      Source    Medium  \
# 0                  2                        0  paypal.com  referral
# 1                  2                        0      google   organic
# 2                  1                        0      google       cpc
# 3                  2                        5    (direct)    (none)
# 4                  2                        0  paypal.com  referral
#
#    Session_Duration   Revenue     Tax Shipping  Quantity
# 0                77  $168.00   $0.00    $6.00         15
# ...

# %%
pd.scatter_matrix(data_csv, figsize=(15, 15), s=150, alpha=0.6, cmap='brg', edgecolors='gray');

# %%
# One-Hot encoding:
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse=True)

data_encoded = ohe.fit_transform(data_csv[['medium']].values)

print data_encoded.shape()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-f5a6b024a0ac> in <module>()
#       3 ohe = OneHotEncoder(sparse=True)
#       4
# ----> 5 data_encoded = ohe.fit_transform(data_csv[['medium']].values)
#       6
#       7 print data_encoded.shape()
#
# C:\Users\asilver\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1670         if isinstance(key, (Series, np.ndarray, list)):
#    1671             # either boolean or fancy integer index
# -> 1672             return self._getitem_array(key)
#    1673         elif isinstance(key, DataFrame):
#    1674             return self._getitem_frame(key)
#
# C:\Users\asilver\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
#    1714             return self.take(indexer, axis=0, convert=False)
# ...

# %%
plt.hist(data_csv['Quantity'], bins=np.arange(0, 20), color='#cccccc')
plt.xlabel("quantity")

# %%
plt.scatter(data_csv['Session_Duration'], data_csv['Quantity'], lw=0, alpha=.8, color='k')
plt.xlabel("Session Duration")
plt.ylabel("Quantity")

# %%
print data_csv[data_csv['Revenue'] == data_csv['Revenue'].min()][['Products', 'City', 'Medium', 'Previous_Sessions','Revenue']]
print data_csv[data_csv['Revenue'] == data_csv['Revenue'].max()][['Products', 'City', 'Medium', 'Previous_Sessions','Revenue']]
# Out:
#       Products      City  Medium  Previous_Sessions Revenue
# 213  Big Smoke  New York  (none)                  1  $1.00
#       Products   City Medium  Previous_Sessions  Revenue
# 2  Black Label  Davis    cpc                  1  $94.00
