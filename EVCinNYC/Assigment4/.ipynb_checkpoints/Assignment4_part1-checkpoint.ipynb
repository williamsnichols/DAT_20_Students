# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#From http://nbviewer.ipython.org/github/cs109/content/blob/master/lec_04_wrangling.ipynb
#QUESTIONS TO REVIEW
#9, 11, 12, 31, 44, 58, 67, Small Multiples
#Getting a standard of how, when to use {} ad [] and () - and sometimes use . vs [] -- see attempt 48

# %%
names = ['imdbID', 'title', 'year', 'score', 'votes', 'runtime', 'genres']
url = '/Users/EVC/GA/upstream/DAT_20_Students/EVCinNYC/Assigment4/imdb_top_10000.txt'
data = pd.read_csv(url, delimiter='\t', names=names).dropna()
print "Number of rows: %i" % data.shape[0]
data.head()
# Out:
# Number of rows: 9999
#       imdbID                            title  year  score   votes    runtime  \
# 0  tt0111161  The Shawshank Redemption (1994)  1994    9.2  619479  142 mins.
# 1  tt0110912              Pulp Fiction (1994)  1994    9.0  490065  154 mins.
# 2  tt0137523                Fight Club (1999)  1999    8.8  458173  139 mins.
# 3  tt0133093                The Matrix (1999)  1999    8.7  448114  136 mins.
# 4  tt1375666                 Inception (2010)  2010    8.9  385149  148 mins.
#
#                              genres
# 0                       Crime|Drama
# 1                    Crime|Thriller
# 2            Drama|Mystery|Thriller
# 3           Action|Adventure|Sci-Fi
# 4  Action|Adventure|Sci-Fi|Thriller

# %%
#let's remove the mins. and turn runtime to a number
dirty = '142 mins.'
number, text = dirty.split(' ')
clean = int(number)
print number
#QUESTION: I tried using the regex for /s instead for space, but came back as bad syntax - would i have to import re?
# Out:
# 142

# %%
#packaging into list comprehension seems a bit odd
#so for everything (r) in the column runtime, 
#the clean data is the float of the item.split() - but I don't get the [0] there
clean_runtime = [float(r.split(' ')[0]) for r in data.runtime]
data['runtime'] = clean_runtime
data.head()
# Out:
#       imdbID                            title  year  score   votes  runtime  \
# 0  tt0111161  The Shawshank Redemption (1994)  1994    9.2  619479      142
# 1  tt0110912              Pulp Fiction (1994)  1994    9.0  490065      154
# 2  tt0137523                Fight Club (1999)  1999    8.8  458173      139
# 3  tt0133093                The Matrix (1999)  1999    8.7  448114      136
# 4  tt1375666                 Inception (2010)  2010    8.9  385149      148
#
#                              genres
# 0                       Crime|Drama
# 1                    Crime|Thriller
# 2            Drama|Mystery|Thriller
# 3           Action|Adventure|Sci-Fi
# 4  Action|Adventure|Sci-Fi|Thriller

# %%
#Splitting up unique dramas that are currently separated by |

genres = set()
for m in data.genres:
    genres.update(g for g in m.split('|'))
genres = sorted(genres)

#making a column for each genre
# I see the true/false statement in data[genres]
# Not sure how this ended up making a column for each
# I see that each genre in genres is getting the true/false
# so the genres.update is updating the list each time a new genre is discovered
# this is definitely twisting my brin

for genre in genres:
    data[genre] = [genre in movie.split('|') for movie in data.genres]

data.head()
# Out:
#       imdbID                            title  year  score   votes  runtime  \
# 0  tt0111161  The Shawshank Redemption (1994)  1994    9.2  619479      142
# 1  tt0110912              Pulp Fiction (1994)  1994    9.0  490065      154
# 2  tt0137523                Fight Club (1999)  1999    8.8  458173      139
# 3  tt0133093                The Matrix (1999)  1999    8.7  448114      136
# 4  tt1375666                 Inception (2010)  2010    8.9  385149      148
#
#                              genres Action  Adult Adventure   ...   Musical  \
# 0                       Crime|Drama  False  False     False   ...     False
# 1                    Crime|Thriller  False  False     False   ...     False
# 2            Drama|Mystery|Thriller  False  False     False   ...     False
# 3           Action|Adventure|Sci-Fi   True  False      True   ...     False
# 4  Action|Adventure|Sci-Fi|Thriller   True  False      True   ...     False
#
# ...

# %%
#Removing year from the title
#This is straight forward - I get it's the field less the last seven digits
data['title'] = [t[0:-7] for t in data.title]
data.head()
# Out:
#       imdbID                     title  year  score   votes  runtime  \
# 0  tt0111161  The Shawshank Redemption  1994    9.2  619479      142
# 1  tt0110912              Pulp Fiction  1994    9.0  490065      154
# 2  tt0137523                Fight Club  1999    8.8  458173      139
# 3  tt0133093                The Matrix  1999    8.7  448114      136
# 4  tt1375666                 Inception  2010    8.9  385149      148
#
#                              genres Action  Adult Adventure   ...   Musical  \
# 0                       Crime|Drama  False  False     False   ...     False
# 1                    Crime|Thriller  False  False     False   ...     False
# 2            Drama|Mystery|Thriller  False  False     False   ...     False
# 3           Action|Adventure|Sci-Fi   True  False      True   ...     False
# 4  Action|Adventure|Sci-Fi|Thriller   True  False      True   ...     False
#
#   Mystery   News Reality-TV Romance Sci-Fi  Sport Thriller    War Western
# ...

# %%
# TIME TO EXPLORE DATA
#I know it need double [[]] to work, so first set is to show
#that we are taking a subset of the array
#the second set is to show it's a list of items, correct?
data[['score','runtime','year','votes']].describe()
# Out:
#              score      runtime         year          votes
# count  9999.000000  9999.000000  9999.000000    9999.000000
# mean      6.385989   103.580358  1993.471447   16605.462946
# std       1.189965    26.629310    14.830049   34564.883945
# min       1.500000     0.000000  1950.000000    1356.000000
# 25%       5.700000    93.000000  1986.000000    2334.500000
# 50%       6.600000   102.000000  1998.000000    4981.000000
# 75%       7.200000   115.000000  2005.000000   15278.500000
# max       9.200000   450.000000  2011.000000  619479.000000

# %%
#looking why a runtime would be 0; mean of 103 seems low, no?
print len(data[data.runtime == 0])
# Out:
# 282

# %%
#so where 0, going to flag then as NAN (Not a Number) so won't be in the describe
# so this is dataframe.attribute[subset of attribute] = renaming it as nan
data.runtime[data.runtime==0] = np.nan
# Out:
# -c:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data.runtime.describe()
# Out:
# count    9717.000000
# mean      106.586395
# std        20.230330
# min        45.000000
# 25%        93.000000
# 50%       103.000000
# 75%       115.000000
# max       450.000000
# Name: runtime, dtype: float64

# %%
#Interesting to me that really didn't change the median - I guess 282 values out of nearly 10K of them is just a small error?
#Do see the standard deviation has reduced from 26 to 20
#That 450 looks like an outlier though, no? How many over 4 hours?
print data[data.runtime > 240]
# Out:
#          imdbID          title  year  score  votes  runtime  \
# 2086  tt0116477         Hamlet  1996    7.7  19698      242
# 2936  tt0107007     Gettysburg  1993    7.7  12093      261
# 6738  tt0063794  War and Peace  1967    7.8   2833      427
# 6908  tt0111341     Satantango  1994    8.5   2698      450
#
#                             genres Action  Adult Adventure   ...   Musical  \
# 2086  Crime|Drama|Romance|Thriller  False  False     False   ...     False
# 2936             Drama|History|War  False  False     False   ...     False
# 6738     Drama|History|Romance|War  False  False     False   ...     False
# 6908          Comedy|Drama|Mystery  False  False     False   ...     False
#
#      Mystery   News Reality-TV Romance Sci-Fi  Sport Thriller    War Western
# 2086   False  False      False    True  False  False     True  False   False
# 2936   False  False      False   False  False  False    False   True   False
# ...

# %%
#Can I do this just getting the movie titles and the runtimes?
over4hr =  data[data.runtime > 240]
print over4hr[['title','runtime']]
# Out:
#               title  runtime
# 2086         Hamlet      242
# 2936     Gettysburg      261
# 6738  War and Peace      427
# 6908     Satantango      450

# %%
#attempt to describe for all movies less than 4 hours
#data.runtime[not over4hr].describe()   doesn't work
#QUESTION: Is there a way to do a parameter for the subset of the data.runtime?
data.runtime[data.runtime<241].describe()
# Out:
# count    9713.000000
# mean      106.488212
# std        19.554235
# min        45.000000
# 25%        93.000000
# 50%       103.000000
# 75%       115.000000
# max       237.000000
# Name: runtime, dtype: float64

# %%
#So some plotting
# here doing histogram, x axis, y axis, 
plt.hist(data.year, bins=np.arange(1950,2013), color='#dddddd')
plt.xlabel("Release Year")
plt.ylabel("# of movies voted on")

# %%
plt.hist(data.score, bins=20, color='#eeeeee')
plt.xlabel("IMDB rating")
plt.ylabel("# of movies receiving this rating")

# %%
plt.hist(data.runtime.dropna(), bins=30, color="#bbbbbb")
plt.xlabel("runtime distribution")

# %%
plt.scatter(data.year, data.score, lw=0, alpha=.08, color='blue')
plt.xlabel("Year")
plt.ylabel("IMDB Rating")

# %%
#definitiely think selection bias here - the only time people
#see old movies is when they are "worth" seeing - they are good

# %%
plt.scatter(data.votes, data.score, lw=0, alpha=.2, color='blue')
plt.xlabel("Number of votes")
plt.ylabel("IMDB Rating")
plt.xscale('log')
#QUESTION: Truthfully - not sure how to read this or the insight from this one, how log covers

# %%
#lots of votes and low scores - seems right
data[(data.votes > 9e4)&(data.score < 5)][['title','year','score','votes','genres']]
#need some better learning on proper [()] usage
# dataFrame[subset]
# dataFrame[subset][[fields to show as a list/array separated by commas]]
# dataFrame[() & ()] so guess this is a little odd, but guess because two arguments to cut thru
# Out:
#               title  year  score  votes                           genres
# 317        New Moon  2009    4.5  90457  Adventure|Drama|Fantasy|Romance
# 334  Batman & Robin  1997    3.5  91875      Action|Crime|Fantasy|Sci-Fi

# %%
data[data.score == data.score.min()][['title','year','score','votes','genres']]
# Out:
#                              title  year  score  votes  \
# 1982      Manos: The Hands of Fate  1966    1.5  20927
# 2793  Superbabies: Baby Geniuses 2  2004    1.5  13196
# 3746             Daniel the Wizard  2004    1.5   8271
# 5158                  Ben & Arthur  2002    1.5   4675
# 5993     Night Train to Mundo Fine  1966    1.5   3542
# 6257               Monster a-Go Go  1965    1.5   3255
# 6726                    Dream Well  2009    1.5   2848
#
#                                   genres
# 1982                              Horror
# 2793                       Comedy|Family
# 3746  Comedy|Crime|Family|Fantasy|Horror
# 5158                       Drama|Romance
# 5993          Action|Adventure|Crime|War
# 6257                       Sci-Fi|Horror
# 6726                Comedy|Romance|Sport

# %%
data[data.score == data.score.max()][['title','year','score','votes','genres']]
# Out:
#                        title  year  score   votes       genres
# 0   The Shawshank Redemption  1994    9.2  619479  Crime|Drama
# 26             The Godfather  1972    9.2  474189  Crime|Drama

# %%
#AGGREGTING
#sum sums over rows by default
#trying to break this down - but not sure I see how splitting out by each genre that is there with |
#so I'm not getting the actual genre name - names are right, just not displaying names; code is identical to example
# determined the [::-1] is two parts {:} is start to finish, 2nd : is to show sort direction
genre_count = np.sort(data[genres].sum())[::-1]
pd.DataFrame({'Genre Count': genre_count})
# Out:
#     Genre Count
# 0          5697
# 1          3922
# 2          2832
# 3          2441
# 4          1891
# 5          1867
# 6          1313
# 7          1215
# 8          1009
# 9           916
# 10          897
# 11          754
# 12          512
# 13          394
# 14          371
# 15          358
# 16          314
# 17          288
# 18          260
# 19          235
# 20           40
# 21            9
# 22            1
# 23            1

# %%
# of genres per movie - axis-1 
genre_count = data[genres].sum(axis=1)
# The % is to fill in with a variable from before; the 0.2f mean two decimals, floating
print "Average movie has %0.2f genres" % genre_count.mean()
genre_count.describe()
# Out:
# Average movie has 2.75 genres
# count    9999.000000
# mean        2.753975
# std         1.168910
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         8.000000
# dtype: float64

# %%
#GROUP PROPERTIES
#Split movies by decade - TRUNCATING THE LAST DIGIT
#So here we are truncating the trailing year, then multiplying by 10 to get decade
#print (1994//10) = 199; then mulitply by 10 to get 1990
decade = (data.year // 10) * 10

#simplifying the data - just selecting the title and year
tyd = data[['title','year']]
#creating a new field in the tyd dataframe that takes the equation and puts in the decade value
tyd['decade'] = decade
tyd.head()
# Out:
#                       title  year  decade
# 0  The Shawshank Redemption  1994    1990
# 1              Pulp Fiction  1994    1990
# 2                Fight Club  1999    1990
# 3                The Matrix  1999    1990
# 4                 Inception  2010    2010

# %%
#Since decade was not in data DataFrame (was in tyd) - how does it get used here?
#mean score for all movies in each decade
decade_mean = data.groupby(decade).score.mean()
decade_mean.name = "Decade Mean"
print decade_mean
# Out:
# year
# 1950    7.244522
# 1960    7.062367
# 1970    6.842297
# 1980    6.248693
# 1990    6.199316
# 2000    6.277858
# 2010    6.344552
# Name: Decade Mean, dtype: float64

# %%
#So here we're doing two graphs on the same index which is pretty cool
#Again plotting is basically plt.graphtype(x, y, arguents)
plt.plot(decade_mean.index, decade_mean.values, 'o-', color = 'r', lw=3, label = "Decade Average")
plt.scatter(data.year, data.score, alpha=.04, lw=0, color = 'blue')
#Then can pretty it up
plt.xlabel("Year")
plt.ylabel("Score")
plt.legend(frameon=False)

# %%
#Again, more recent movies people saw; older movies are ones they wanted to see because ostensibly better
#More detail - scatter in each year...

# %%
#grouped_scores = data.groupby(decade).score
#fill_between(x,y1,y2) and hear we are doing +1 std dev and -1 std dev

grouped_scores = data.groupby(decade).score
mean = grouped_scores.mean()
std = grouped_scores.std()

plt.plot(decade_mean.index, decade_mean.values, 'o-', color = 'r', lw=3, label='Decade Avg')
plt.fill_between(decade_mean.index, (decade_mean + std).values, (decade_mean - std).values, color = 'r', alpha=.2)
plt.scatter(data.year, data.score, alpha=.04, lw=0, color='k')

plt.xlabel("Year")
plt.ylabel("Score")
plt.legend(frameon=False)

# %%
#Here is nice look at highest rated movie by year
#Haven't seen this FOR before
for year, subset in data.groupby('year'):
    print year, subset[(subset.score == subset.score.min())].title.values
#What is best way to cut this by specific years?
#NOPE: print year, subset[(subset.score == subset.score.max())&(subset.year[1970:1990])].title.values
# Out:
# 1950 ['Abbott and Costello in the Foreign Legion']
# 1951 ['Flying Leathernecks']
# 1952 ['The Snows of Kilimanjaro']
# 1953 ['Robot Monster']
# 1954 ['The Last Time I Saw Paris']
# 1955 ['Bride of the Monster']
# 1956 ['The Conqueror']
# 1957 ['20 Million Miles to Earth' 'Raintree County']
# 1958 ['The Screaming Skull']
# 1959 ['Prince of Space']
# 1960 ['Body in the Web']
# 1961 ['The Beast of Yucca Flats']
# 1962 ['Eegah']
# 1963 ['The Skydivers']
# 1964 ['The Starfighters']
# 1965 ['Monster a-Go Go']
# 1966 ['Manos: The Hands of Fate' 'Night Train to Mundo Fine']
# 1967 ['Valley of the Dolls']
# 1968 ['Girl in Gold Boots']
# 1969 ['Hercules in New York']
# 1970 ['Myra Breckinridge']
# 1971 ['Zaat']
# 1972 ['Night of the Lepus']
# 1973 ['Godzilla vs. Megalon']
# 1974 ['Flesh Gordon']
# 1975 ['Mitchell']
# 1976 ['Track of the Moon Beast']
# 1977 ['The Incredible Melting Man']
# 1978 ['Laserblast']
# 1979 ['The Clonus Horror']
# 1980 ['The Pumaman']
# 1981 ['Zombie Lake']
# 1982
# ...

# %%
#SMALL MULTIPLES
#Create 4x6 grid of plots
#I'm not getting this to work - not sure why a key error?  Not sure what zip(axes.ravel()) as not really definied?

fig, axes = plt.subplots(nrows=4, ncols=6, figsize=(12,8), tight_layout=True)

bins = np.arange(1950, 2013, 3)
for ax, genre in zip(axes.ravel(), genres):
    ax.hist(data[data[genre] == 1].year, bins=bins, histtype='stepfilled', normed=True, color='r', alpha=.3, ec='none')
    ax.hist(data.year, ins=bins, histtype='stepfilled', ec='None', normed=True, zorder=0, color='#cccccc')
    ax.annotate(genre, xy=(1955, 3e-2), fontsize=14)
    ax.xaxis.set_ticks(np.arrange(1950,2013,30))
    ax.set_yticks([])
    ax.set_xlabel("Year")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-43a1a733e29e> in <module>()
#       6 bins = np.arange(1950, 2013, 3)
#       7 for ax, genre in zip(axes.ravel(), genres):
# ----> 8     ax.hist(data[data[genre] == 1].year, bins=bins, histtype='stepfilled', normed=True, color='r', alpha=.3, ec='none')
#       9     ax.hist(data.year, ins=bins, histtype='stepfilled', ec='None', normed=True, zorder=0, color='#cccccc')
#      10     ax.annotate(genre, xy=(1955, 3e-2), fontsize=14)
#
# //anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5602         # Massage 'x' for processing.
#    5603         # NOTE: Be sure any changes here is also done below to 'weights'
# ...

# %%
#CONTINUE to see key error and can't figure out why
fig, axes = plt.subplots(nrows=4, ncols=6, figsize=(12, 8), tight_layout=True)
bins = np.arange(30,240,10)

for ax, genre in zip(axes.ravel(), genres):
    ax.hist(data[data[genre] == 1].runtime, 
            bins=bins, histtype='stepfilled', color='r', ec='none', alpha=.3, normed=True)
    ax.hist(data.runtime, bins=bins, normed=True, histtype='stepfilled', color='#cccccc', ec='none', zorder=0)
    ax.set_xticks(np.arange(30,240,60))
    ax.set_yticks([])
    ax.set_xlabel("runtime min")
    ax.annotate(genre, xy=(230, .02), ha='right', fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-5d273c8e68d1> in <module>()
#       4
#       5 for ax, genre in zip(axes.ravel(), genres):
# ----> 6     ax.hist(data[data[genre] == 1].runtime, bins=bins, histtype='stepfilled', color='r', ec='none', alpha=.3, normed=True)
#       7     ax.hist(data.runtime, bins=bins, normed=True, histtype='stepfilled', color='#cccccc', ec='none', zorder=0)
#       8     ax.set_xticks(np.arange(30,240,60))
#
# //anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5602         # Massage 'x' for processing.
#    5603         # NOTE: Be sure any changes here is also done below to 'weights'
# -> 5604         if isinstance(x, np.ndarray) or not iterable(x[0]):
# ...

# %%
fig, axes = plt.subplots(nrows=4, ncols=6, figsize=(12, 8), tight_layout=True)

bins = np.arange(0, 10, .5)

for ax, genre in zip(axes.ravel(), genres):
    ax.hist(data[data[genre] == 1].score, 
            bins=bins, histtype='stepfilled', color='r', ec='none', alpha=.3, normed=True)
               
    ax.hist(data.score, bins=bins, normed=True,
            histtype='stepfilled', ec='none', color='#cccccc',
            zorder=0)
    
    ax.set_yticks([])
    ax.set_xlabel("Score")
    remove_border(ax, left=False)
    ax.set_ylim(0, .4)
    ax.annotate(genre, xy=(0, .2), ha='left', fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-5f241d1df81d> in <module>()
#       5 for ax, genre in zip(axes.ravel(), genres):
#       6     ax.hist(data[data[genre] == 1].score,
# ----> 7             bins=bins, histtype='stepfilled', color='r', ec='none', alpha=.3, normed=True)
#       8
#       9     ax.hist(data.score, bins=bins, normed=True,
#
# //anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5602         # Massage 'x' for processing.
#    5603         # NOTE: Be sure any changes here is also done below to 'weights'
# -> 5604         if isinstance(x, np.ndarray) or not iterable(x[0]):
#    5605             # TODO: support masked arrays;
#    5606             x = np.asarray(x)
#
# ...

# %%
#TWO NEW PLOTS
data.head(10)
# Out:
#       imdbID                                           title  year  score  \
# 0  tt0111161                        The Shawshank Redemption  1994    9.2
# 1  tt0110912                                    Pulp Fiction  1994    9.0
# 2  tt0137523                                      Fight Club  1999    8.8
# 3  tt0133093                                      The Matrix  1999    8.7
# 4  tt1375666                                       Inception  2010    8.9
# 5  tt0109830                                    Forrest Gump  1994    8.7
# 6  tt0169547                                 American Beauty  1999    8.6
# 7  tt0499549                                          Avatar  2009    8.1
# 8  tt0108052                                Schindler's List  1993    8.9
# 9  tt0080684  Star Wars: Episode V - The Empire Strikes Back  1980    8.8
#
#     votes  runtime                            genres Action  Adult Adventure  \
# ...

# %%
#Do users give higher scores to shorter movies?

# %%
#Try to reduce that to just movies under four hours
plt.scatter(data.runtime[(data.runtime<241) & (data.runtime>60)],data.score[(data.runtime<241) & (data.runtime>60)], lw=0, alpha=.08, color='blue')

plt.xlabel("Runtime")
plt.ylabel("IMDB Rating")

# %%
#Is that just because longer running movies are older movies?

# %%
plt.scatter(data.runtime[(data.runtime<241) & (data.runtime>60)],data.year[(data.runtime<241) & (data.runtime>60)], lw=0, alpha=.08, color='blue')

plt.xlabel("Runtime")
plt.ylabel("Year")
