# %%
# %%html
# <link rel="stylesheet" href="static/hyrule.css" type="text/css">
# Out:
# <link rel="stylesheet" href="static/hyrule.css" type="text/css">

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import linear_model
import statsmodels.formula.api as smf

#tell pandas to display wide tables as pretty HTML tables
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %% [markdown]
# # Part I.
#
# 1. Read in the bikeshare data to a pandas dataframe just as you did for the previous assignment.
# 2. Split the dataframe horizontally into two separate dataframes each having N/2 rows. Call the dataframe with first N/2 rows bikeshare_train, and the latter half bikeshare_test
# 3. Using the bikeshare_train dataframe run a regression with cnt as our target variable, and temp, atemp, hum, workingday, hour, weathersit as the feature variables. Specify the R^2 value. We'll call this our training model The resulting model should have one more coefficient than the number of feature variables.
# 4. Describe the error (in terms of R^2) between the model you just calculated and the bikeshare_test. Is this higher or lower than the R^2 of the previous step? What's the reason for this difference?
# 4. Create a binary variable for rush hour defined by 6-9am & 4-6pm.
# 5. Run the regression again. Using a similar process used in steps 2 and 3, assert whether this improves the results or not. Why? (You should be able to explain this quantitatively)

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ga-students/DAT_20_NYC/master/Data/bikeshare.csv?token=AGIEIobNiWR-QhMNd48iTRygzpZEN0p8ks5VJe-wwA%3D%3D', 
                index_col=0)

data.describe()
# Out:
#              season            yr          mnth            hr       holiday       weekday    workingday    weathersit          temp         atemp           hum     windspeed        casual    registered           cnt
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775     11.546752      0.028770      3.003683      0.682721      1.425283      0.496987      0.475775      0.627229      0.190098     35.676218    153.786869    189.463088
# std        1.106918      0.500008      3.438776      6.914405      0.167165      2.005771      0.465431      0.639357      0.192556      0.171850      0.192930      0.122340     49.305030    151.357286    181.387599
# min        1.000000      0.000000      1.000000      0.000000      0.000000      0.000000      0.000000      1.000000      0.020000      0.000000      0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        2.000000      0.000000      4.000000      6.000000      0.000000      1.000000      0.000000      1.000000      0.340000      0.333300      0.480000      0.104500      4.000000     34.000000     40.000000
# 50%        3.000000      1.000000      7.000000     12.000000      0.000000      3.000000      1.000000      1.000000      0.500000      0.484800      0.630000      0.194000     17.000000    115.000000    142.000000
# 75%        3.000000      1.000000     10.000000     18.000000      0.000000      5.000000      1.000000      2.000000      0.660000      0.621200      0.780000      0.253700     48.000000    220.000000    281.000000
# max        4.000000      1.000000     12.000000     23.000000      1.000000      6.000000      1.000000      4.000000      1.000000      1.000000      1.000000      0.850700    367.000000    886.000000    977.000000

# %%
data.head()

print len(data)
# Out:
# 17379

# %% [markdown]
# # Starting with simple linear regression

# %%
fig, axs = plt.subplots(1, 4, sharey=True)
data.plot(kind='scatter', x='temp', y='cnt', ax=axs[0], figsize=(16, 8))
data.plot(kind='scatter', x='atemp', y='cnt', ax=axs[1])
data.plot(kind='scatter', x='hum', y='cnt', ax=axs[2])
# data.plot(kind='scatter', x='workingday', y='cnt', ax=axs[3])
# data.plot(kind='scatter', x='hr', y='cnt', ax=axs[3])
data.plot(kind='scatter', x='temp', y='cnt', ax=axs[3])


# emp, atemp, hum, workingday, hour, weathersit

# %%
# split dataframe in half
bikeshare_train = pd.DataFrame()
bikeshare_test = pd.DataFrame()

bikeshare_train = data[:len(data)/2]
bikeshare_test = data[len(data)/2:]

# confirm that there are two data frames, each with n/2 rows
print type(bikeshare_train); print len(bikeshare_train)
print type(bikeshare_test); print len(bikeshare_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 8689
# <class 'pandas.core.frame.DataFrame'>
# 8690

# %%
# describe first half 
bikeshare_train.describe()
# Out:
#             season           yr         mnth           hr      holiday      weekday   workingday   weathersit         temp        atemp          hum    windspeed       casual   registered          cnt
# count  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000  8689.000000
# mean      2.505927     0.005064     6.545747    11.570607     0.029808     2.999770     0.680285     1.436299     0.488259     0.468258     0.642945     0.191508    28.561860   114.976982   143.538842
# std       1.107896     0.070985     3.442270     6.906146     0.170067     2.009817     0.466393     0.653383     0.197847     0.176721     0.196387     0.123350    38.793085   109.292093   133.612670
# min       1.000000     0.000000     1.000000     0.000000     0.000000     0.000000     0.000000     1.000000     0.020000     0.000000     0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       2.000000     0.000000     4.000000     6.000000     0.000000     1.000000     0.000000     1.000000     0.320000     0.318200     0.490000     0.104500     3.000000    26.000000    31.000000
# 50%       3.000000     0.000000     7.000000    12.000000     0.000000     3.000000     1.000000     1.000000     0.500000     0.484800     0.650000     0.194000    14.000000    89.000000   109.000000
# 75%       3.000000     0.000000    10.000000    18.000000     0.000000     5.000000     1.000000     2.000000     0.660000     0.621200     0.810000     0.283600    38.000000   167.000000   210.000000
# max       4.000000     1.000000    12.000000    23.000000     1.000000     6.000000     1.000000     4.000000     0.960000     1.000000     1.000000     0.850700   272.000000   567.000000   651.000000

# %%
# describe second half
bikeshare_test.describe()
# Out:
#             season    yr         mnth           hr      holiday      weekday   workingday   weathersit         temp        atemp          hum    windspeed       casual   registered          cnt
# count  8690.000000  8690  8690.000000  8690.000000  8690.000000  8690.000000  8690.000000  8690.000000  8690.000000  8690.000000  8690.000000  8690.000000  8690.000000  8690.000000  8690.000000
# mean      2.497353     1     6.529804    11.522900     0.027733     3.007595     0.685155     1.414269     0.505715     0.483292     0.611514     0.188687    42.789758   192.592290   235.382048
# std       1.105987     0     3.435458     6.922968     0.164216     2.001826     0.464481     0.624861     0.186720     0.166509     0.188113     0.121313    57.061541   175.677055   209.128671
# min       1.000000     1     1.000000     0.000000     0.000000     0.000000     0.000000     1.000000     0.020000     0.015200     0.160000     0.000000     0.000000     0.000000     1.000000
# 25%       2.000000     1     4.000000     6.000000     0.000000     1.000000     0.000000     1.000000     0.340000     0.333300     0.460000     0.104500     5.000000    46.000000    53.250000
# 50%       3.000000     1     7.000000    12.000000     0.000000     3.000000     1.000000     1.000000     0.520000     0.500000     0.610000     0.164200    20.000000   156.000000   192.000000
# 75%       3.000000     1     9.000000    18.000000     0.000000     5.000000     1.000000     2.000000     0.660000     0.621200     0.770000     0.253700    60.000000   276.000000   349.000000
# max       4.000000     1    12.000000    23.000000     1.000000     6.000000     1.000000     4.000000     1.000000     0.924200     1.000000     0.806000   367.000000   886.000000   977.000000

# %%
# create a model for the bikeshare_train, the first half of the whole dataframe
lm_train = smf.ols(formula='cnt ~ temp + atemp + hum + workingday + hr + weathersit', data=bikeshare_train).fit()
 
# print the coefficients
lm_train.params
# Out:
# Intercept      24.428790
# temp          137.351792
# atemp         153.756465
# hum          -127.719737
# workingday     -1.073853
# hr              6.031383
# weathersit     -4.797226
# dtype: float64

# %%
# print summary 
lm_train.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.367
# Model:                            OLS   Adj. R-squared:                  0.367
# Method:                 Least Squares   F-statistic:                     839.3
# Date:                Wed, 08 Apr 2015   Prob (F-statistic):               0.00
# Time:                        22:30:25   Log-Likelihood:                -52873.
# No. Observations:                8689   AIC:                         1.058e+05
# Df Residuals:                    8682   BIC:                         1.058e+05
# Df Model:                           6
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     24.4288      5.975      4.089      0.000        12.717    36.140
# temp         137.3518     46.304      2.966      0.003        46.585   228.119
# atemp        153.7565     51.876      2.964      0.003        52.067   255.446
# hum         -127.7197      6.686    -19.101      0.000      -140.827  -114.613
# workingday    -1.0739      2.457     -0.437      0.662        -5.891     3.743
# hr             6.0314      0.173     34.895      0.000         5.693     6.370
# weathersit    -4.7972      1.944     -2.467      0.014        -8.608    -0.986
# ==============================================================================
# Omnibus:                     1474.307   Durbin-Watson:                   0.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2499.956
# Skew:                           1.118   Prob(JB):                         0.00
# Kurtosis:                       4.380   Cond. No.                         827.
# ==============================================================================
# """

# %%
# create a model for the bikeshare_test, the second half of the whole dataframe
lm_test = smf.ols(formula='cnt ~ temp + atemp + hum + workingday + hr + weathersit', data=bikeshare_test).fit()
 
# print the coefficients
lm_test.params
# Out:
# Intercept      79.142217
# temp          113.684988
# atemp         286.805585
# hum          -245.038371
# workingday     11.312807
# hr              9.251564
# weathersit     -3.093101
# dtype: float64

# %%
# print summary 
lm_test.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     743.0
# Date:                Wed, 08 Apr 2015   Prob (F-statistic):               0.00
# Time:                        22:30:25   Log-Likelihood:                -56960.
# No. Observations:                8690   AIC:                         1.139e+05
# Df Residuals:                    8683   BIC:                         1.140e+05
# Df Model:                           6
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     79.1422     10.005      7.910      0.000        59.530    98.754
# temp         113.6850     53.231      2.136      0.033         9.340   218.030
# atemp        286.8056     59.677      4.806      0.000       169.825   403.786
# hum         -245.0384     11.452    -21.398      0.000      -267.486  -222.590
# workingday    11.3128      3.934      2.876      0.004         3.601    19.024
# hr             9.2516      0.282     32.803      0.000         8.699     9.804
# weathersit    -3.0931      3.285     -0.942      0.346        -9.532     3.345
# ==============================================================================
# Omnibus:                     1462.254   Durbin-Watson:                   0.556
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2396.319
# Skew:                           1.138   Prob(JB):                         0.00
# Kurtosis:                       4.199   Cond. No.                         592.
# ==============================================================================
# """

# %% [markdown]
# ## Difference between models in terms of r-squared
# - dataframe bikeshare_train has an r^2 of 0.367
# - dataframe bikeshare_test has an r^2 of 0.339
# - this represents a difference of 0.028; r^2 for the second model is 0.028 lower than the previous model
# - this is a relatively small difference and can be explained by the variance in observations between two randomly selected dataframes
# - if the original dataset were smaller, we could expect the difference in r^2 to be greater. As the size of the orginal data were much larger -- in the 100,000's or millions of rows -- r^2 would get smaller and smaller, as a random sampling of half of all observations would be more similar to the other half

# %% [markdown]
# 4. Create a binary variable for rush hour defined by 6-9am & 4-6pm.
# 5. Run the regression again. Using a similar process used in steps 2 and 3, assert whether this improves the results or not. Why? (You should be able to explain this quantitatively)

# %%
lm_rush_hour = data.
# Out:
#   File "<ipython-input-17-aab47a76e608>", line 1
#     lm_rush_hour = data.
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Part II:
#
# Provide answers to these questions in your own words:
#
# 1. The error you calculated in step 4 is called generalization error. Explain why it's called generalization error and why it's important when evaluating our regression model.
# 2. Of the features you used for regression above, which one best explains cnt?
# 3. Which variables in the dataset are correlated and how do these affect your regression?
# 4. How would the p-value of our regression change as we took smaller subsets of the dataframe to build our training model?

# %% [markdown]
# Bonus:
#
# - Experiment with using some of the other variables in the dataset to improve your model
# - Try using polynomial regression to improve your model

# %%
data['rush_hour'] = data['hr'].map(lambda x: 1 if 6 < x < 9 or 16 < x < 18 else 0)

data.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  rush_hour
# instant
# 1        2011-01-01       1   0     1   0        0        6           0           1  0.24  0.2879  0.81          0       3          13   16          0
# 2        2011-01-01       1   0     1   1        0        6           0           1  0.22  0.2727  0.80          0       8          32   40          0
# 3        2011-01-01       1   0     1   2        0        6           0           1  0.22  0.2727  0.80          0       5          27   32          0
# 4        2011-01-01       1   0     1   3        0        6           0           1  0.24  0.2879  0.75          0       3          10   13          0
# 5        2011-01-01       1   0     1   4        0        6           0           1  0.24  0.2879  0.75          0       0           1    1          0
