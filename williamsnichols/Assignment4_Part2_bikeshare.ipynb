# %% [markdown]
# n the data folder you'll find included the file bikeshare.csv. This file contains data related to number of riders (casual, members, and total) for each hour, compared to stats for that time, such as temperature, windspeed. the filebikeshare.txt will explain it in more detail.
#
# Goals:
#
# Explore the data in both hourly and daily counts. You'll need to aggregate by day to generate the daily data.
# Visualise the relationships between the ridership and different features.
# Explain which features seem to be the strongest indicators for each type of ridership (casual and noncasual). Do certain features come off as better tells for one over the other?
# Summarise your results.
# Extra: Business application. Given this information, what suggestions could be made to improve the ridership program? Consider this open field, since we only have aggregated stats and not individual ridership here.
# What's due:
#
# ## For part II:
# A notebook that goes through the data exploration model
# acquires and imports the data
# cleans it up (create the daily from the hourly)
# explores the two data sets for patterns
# summarises and explains the results
# Please upload this notebook to your github (the .ipynb file), or copy and paste the file's contents into a gist.

# %%
# %%html
# <link rel="stylesheet" href="static/hyrule.css" type="text/css">
# Out:
# <link rel="stylesheet" href="static/hyrule.css" type="text/css">

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#tell pandas to display wide tables as pretty HTML tables
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %%
# names = ['instant', 
#          'dteday',
#          'season',
#          'yr',
#          'mnth',
#          'hr',
#          'holiday',
#          'weekday',
#          'workingday',
#          'weathersit',
#          'temp',
#          'atemp',
#          'hum',
#          'windspeed',
#          'casual',
#          'registered',
#          'cnt'
# ]
data = pd.read_csv('https://raw.githubusercontent.com/ga-students/DAT_20_NYC/master/Data/bikeshare.csv?token=AGIEIobNiWR-QhMNd48iTRygzpZEN0p8ks5VJe-wwA%3D%3D', 
                index_col=0)

data.describe()
# Out:
#              season            yr          mnth            hr       holiday       weekday    workingday    weathersit          temp         atemp           hum     windspeed        casual    registered           cnt
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775     11.546752      0.028770      3.003683      0.682721      1.425283      0.496987      0.475775      0.627229      0.190098     35.676218    153.786869    189.463088
# std        1.106918      0.500008      3.438776      6.914405      0.167165      2.005771      0.465431      0.639357      0.192556      0.171850      0.192930      0.122340     49.305030    151.357286    181.387599
# ...

# %%
data.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1        2011-01-01       1   0     1   0        0        6           0           1  0.24  0.2879  0.81          0       3          13   16
# 2        2011-01-01       1   0     1   1        0        6           0           1  0.22  0.2727  0.80          0       8          32   40
# 3        2011-01-01       1   0     1   2        0        6           0           1  0.22  0.2727  0.80          0       5          27   32
# 4        2011-01-01       1   0     1   3        0        6           0           1  0.24  0.2879  0.75          0       3          10   13
# 5        2011-01-01       1   0     1   4        0        6           0           1  0.24  0.2879  0.75          0       0           1    1

# %%
# Create a groupby object:
holidays = data.groupby('holiday')
print type(holidays)

# groupby objects allow for some standard pandas calls:

holidays.describe()
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
#                       atemp        casual           cnt            hr           hum          mnth    registered        season          temp    weathersit       weekday     windspeed    workingday            yr
# holiday
# 0       count  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000  16879.000000
#         mean       0.476691     35.408377    190.428580     11.546182      0.627580      6.526868    155.020203      2.503466      0.497893      1.427158      3.038924      0.190014      0.702944      0.501985
#         std        0.171265     48.963745    181.981435      6.914531      0.193331      3.423080    152.210779      1.103473      0.191986      0.641339      2.010127      0.122223      0.456975      0.500011
# ...

# %%
# Create a groupby object:
weekdays = data.groupby('weekday')
print type(weekdays)

# groupby objects allow for some standard pandas calls:

weekdays.describe()
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
#                      atemp       casual          cnt      holiday           hr          hum         mnth   registered       season         temp   weathersit    windspeed   workingday           yr
# weekday
# 0       count  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000
#         mean      0.465507    56.163469   177.468825     0.000000    11.555156     0.627994     6.487210   121.305356     2.490408     0.483821     1.362110     0.188093     0.000000     0.507994
#         std       0.175384    68.090663   168.167710     0.000000     6.916186     0.185472     3.466126   105.972899     1.122143     0.194458     0.605165     0.119804     0.000000     0.500036
# ...

# %%
#mean cnt by hour of day
hr_mean = data.groupby(data.hr).mean()
hr_mean.name = 'Hourly Mean Cnt'

plt.plot(hr_mean)
plt.legend(data.hr)

# %%
sun = data.registered[data.weekday == 0] 
mon = data.registered[data.weekday == 1]
tue = data.registered[data.weekday == 2]
wed = data.registered[data.weekday == 3]
thu = data.registered[data.weekday == 4]
fri = data.registered[data.weekday == 5]
sat = data.registered[data.weekday == 6]

plt.boxplot([sun, mon, tue, wed, thu, fri, sat]) 
plt.ylabel("Daily ridership") 
plt.xlabel("Day of week")
plt.xticks([1, 2, 3, 4, 5, 6, 7], ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"])
# Out:
# ([<matplotlib.axis.XTick at 0x10e7789d0>,
# ...
#  <a list of 7 Text xticklabel objects>)

# %%
sun = data.casual[data.weekday == 0] 
mon = data.casual[data.weekday == 1]
tue = data.casual[data.weekday == 2]
wed = data.casual[data.weekday == 3]
thu = data.casual[data.weekday == 4]
fri = data.casual[data.weekday == 5]
sat = data.casual[data.weekday == 6]

plt.boxplot([sun, mon, tue, wed, thu, fri, sat]) 
plt.ylabel("Daily ridership") 
plt.xlabel("Day of week")
plt.xticks([1, 2, 3, 4, 5, 6, 7], ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c578e0f37cfd> in <module>()
# ----> 1 sun = data.casual[data.weekday == 0]
#       2 mon = data.casual[data.weekday == 1]
#       3 tue = data.casual[data.weekday == 2]
#       4 wed = data.casual[data.weekday == 3]
#       5 thu = data.casual[data.weekday == 4]
#
# NameError: name 'data' is not defined

# %%
plt.scatter(data.hr,data.cnt)

# %%
# Create a groupby object:
hod = data.groupby('hr')
print type(hod)

# groupby objects allow for some standard pandas calls:

hod.describe()

plt.hist(data.cnt)
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-7129078d66e8> in <module>()
#       7 hod.describe()
#       8
# ----> 9 plt.hist(data.cnt)
#
# /Users/wnichols/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2888                       histtype=histtype, align=align, orientation=orientation,
#    2889                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2890                       stacked=stacked, **kwargs)
#    2891         draw_if_interactive()
#    2892     finally:
#
# ...
